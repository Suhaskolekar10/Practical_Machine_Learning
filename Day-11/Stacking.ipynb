# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,StratifiedKFold,RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,StackingClassifier
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,log_loss

# %%
bcancer=pd.read_csv('BreastCancer.csv',index_col=0)
lbl=LabelEncoder()
bcancer['Class']=lbl.fit_transform(bcancer['Class'])
X=bcancer.drop('Class',axis=1)
y=bcancer['Class']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=23,test_size=0.3)

# %%
lr=LogisticRegression()
svm=SVC(kernel='linear',probability=True,random_state=23)
dtc=DecisionTreeClassifier(random_state=23)
rf=RandomForestClassifier(random_state=23)

# %%
#Without PassThrough
stack=StackingClassifier([('LR',lr),('SVM',svm),('TREE',dtc)],final_estimator=rf)
stack.fit(X_train,y_train) #Excludes all ops on train set
y_pred= stack.predict(X_test)   #excludes all operation on test set
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9333333333333333

# %%
#With PassThrough
stack=StackingClassifier([('LR',lr),('SVM',svm),('TREE',dtc)],final_estimator=rf,passthrough=True)
stack.fit(X_train,y_train) #Excludes all ops on train set
y_pred= stack.predict(X_test)   #excludes all operation on test set
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9571428571428572

# %%
################################### Other Models ###################################

# %%
gbm=GradientBoostingClassifier(random_state=23)
stack=StackingClassifier([('LR',lr),('SVM',svm),('TREE',dtc)],final_estimator=gbm,passthrough=True)
stack.fit(X_train,y_train) #Excludes all ops on train set
y_pred= stack.predict(X_test)   #excludes all operation on test set
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9523809523809523

# %%
#Grid search CV
gbm=GradientBoostingClassifier(random_state=23)
stack=StackingClassifier([('LR',lr),('SVM',svm),('TREE',dtc)],final_estimator=gbm,passthrough=True)
params={'TREE__max_depth':[2,3,4,5,6,None],
        'TREE__min_samples_split':[2,5,10],
        'TREE__min_samples_leaf':[1,3,5,7,10,15],
       'LR__penalty':['l1','l2',None],
       'SVM__C':np.linspace(0.001,3,5),}
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
gcv_stack=RandomizedSearchCV(stack,param_distributions=params,cv=kfold,scoring='neg_log_loss',verbose=3,n_iter=50)
gcv_stack.fit(X,y)
print(gcv_stack.best_params_)
print(gcv_stack.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.184 total time=   1.1s
# [CV 2/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.114 total time=   1.0s
# [CV 3/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.050 total time=   1.0s
# [CV 4/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.185 total time=   1.0s
# [CV 5/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.260 total time=   0.7s
# [CV 1/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=5;, score=-0.176 total time=   0.8s
# [CV 2/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=5;, score=-0.103 total time=   0.7s
# [CV 3/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=5;, score=-0.064 total time=   0.6s
# [CV 4/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=5;, score=-0.177 total time=   0.6s
# [CV 5/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=5;, score=-0.266 total time=   0.6s
# [CV 1/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=-0.130 total time=   1.1s
# [CV 2/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=-0.110 total time=   1.0s
# [CV 3/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=-0.048 total time=   1.0s
# [CV 4/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=-0.172 total time=   1.0s
# [CV 5/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=-0.248 total time=   1.1s
# [CV 1/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.177 total time=   0.8s
# [CV 2/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.103 total time=   0.8s
# [CV 3/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.061 total time=   0.8s
# [CV 4/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.178 total time=   0.8s
# [CV 5/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.248 total time=   0.8s
# [CV 1/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.167 total time=   0.8s
# [CV 2/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.100 total time=   0.8s
# [CV 3/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.065 total time=   0.8s
# [CV 4/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.176 total time=   0.9s
# [CV 5/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.245 total time=   0.8s
# [CV 1/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=15, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=15, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=15, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=15, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=15, TREE__min_samples_split=10;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=3, TREE__min_samples_leaf=5, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=3, TREE__min_samples_leaf=5, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=3, TREE__min_samples_leaf=5, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=3, TREE__min_samples_leaf=5, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=2.25025, TREE__max_depth=3, TREE__min_samples_leaf=5, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=5, TREE__min_samples_leaf=5, TREE__min_samples_split=5;, score=-0.143 total time=   1.4s
# [CV 2/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=5, TREE__min_samples_leaf=5, TREE__min_samples_split=5;, score=-0.128 total time=   1.5s
# [CV 3/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=5, TREE__min_samples_leaf=5, TREE__min_samples_split=5;, score=-0
SVM__C=1.5005, TREE__max_depth=6, TREE__min_samples_leaf=10, TREE__min_samples_split=2;, score=-0.222 total time=   0.9s
# [CV 1/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=3, TREE__min_samples_leaf=10, TREE__min_samples_split=10;, score=-0.183 total time=   1.1s
# [CV 2/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=3, TREE__min_samples_leaf=10, TREE__min_samples_split=10;, score=-0.101 total time=   1.2s
# [CV 3/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=3, TREE__min_samples_leaf=10, TREE__min_samples_split=10;, score=-0.066 total time=   1.1s
# [CV 4/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=3, TREE__min_samples_leaf=10, TREE__min_samples_split=10;, score=-0.176 total time=   1.1s
# [CV 5/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=3, TREE__min_samples_leaf=10, TREE__min_samples_split=10;, score=-0.246 total time=   1.0s
# [CV 1/5] END LR__penalty=l2, SVM__C=0.001, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.165 total time=   0.8s
# [CV 2/5] END LR__penalty=l2, SVM__C=0.001, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.094 total time=   0.8s
# [CV 3/5] END LR__penalty=l2, SVM__C=0.001, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.053 total time=   0.8s
# [CV 4/5] END LR__penalty=l2, SVM__C=0.001, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.163 total time=   0.8s
# [CV 5/5] END LR__penalty=l2, SVM__C=0.001, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.260 total time=   0.8s
# [CV 1/5] END LR__penalty=None, SVM__C=0.75075, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.126 total time=   1.0s
# [CV 2/5] END LR__penalty=None, SVM__C=0.75075, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.111 total time=   1.0s
# [CV 3/5] END LR__penalty=None, SVM__C=0.75075, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.055 total time=   0.9s
# [CV 4/5] END LR__penalty=None, SVM__C=0.75075, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.174 total time=   0.9s
# [CV 5/5] END LR__penalty=None, SVM__C=0.75075, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.249 total time=   0.7s
# [CV 1/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.130 total time=   1.0s
# [CV 2/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.110 total time=   1.1s
# [CV 3/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.048 total time=   0.9s
# [CV 4/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.172 total time=   1.3s
# [CV 5/5] END LR__penalty=None, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.248 total time=   1.1s
# [CV 1/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=3, TREE__min_samples_split=2;, score=-0.169 total time=   0.7s
# [CV 2/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=3, TREE__min_samples_split=2;, score=-0.108 total time=   0.9s
# [CV 3/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=3, TREE__min_samples_split=2;, score=-0.045 total time=   1.0s
# [CV 4/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=3, TREE__min_samples_split=2;, score=-0.173 total time=   0.9s
# [CV 5/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=3, TREE__min_samples_split=2;, score=-0.241 total time=   0.9s
# [CV 1/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=5, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.164 total time=   0.8s
# [CV 2/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=5, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.106 total time=   0.8s
# [CV 3/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=5, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.048 total time=   0.8s
# [CV 4/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=5, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.180 total time=   0.8s
# [CV 5/5] END LR__penalty=None, SVM__C=0.001, TREE__max_depth=5, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=-0.242 total time=   0.8s
# [CV 1/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.149 total time=   0.9s
# [CV 2/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.124 total time=   0.8s
# [CV 3/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.048 total time=   0.7s
# [CV 4/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.186 total time=   0.8s
# [CV 5/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=6, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.241 total time=   0.7s
# [CV 1/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=-0.184 total time=   0.7s
# [CV 2/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=-0.114 total time=   0.7s
# [CV 3/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=-0.050 total time=   0.7s
# [CV 4/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=-0.185 total time=   0.7s
# [CV 5/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=-0.260 total time=   0.6s
# [CV 1/5] END LR__penalty=None, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=-0.158 total time=   0.9s
# [CV 2/5] END LR__penalty=None, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=-0.111 total time=   1.1s
# [CV 3/5] END LR__penalty=None, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=-0.057 total time=   1.1s
# [CV 4/5] END LR__penalty=None, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=-0.152 total time=   1.4s
# [CV 5/5] END LR__penalty=None, SVM__C=2.25025, TREE__max_depth=None, TREE__min_samples_leaf=3, TREE__min_samples_split=10;, score=-0.242 total time=   1.3s
# [CV 1/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.173 total time=   0.9s
# [CV 2/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.111 total time=   0.9s
# [CV 3/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.054 total time=   0.8s
# [CV 4/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.181 total time=   0.8s
# [CV 5/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.263 total time=   0.7s
# [CV 1/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=-0.143 total time=   0.9s
# [CV 2/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=-0.110 total time=   1.3s
# [CV 3/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=-0.049 total time=   1.3s
# [CV 4/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=-0.171 total time=   1.3s
# [CV 5/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=4, TREE__min_samples_leaf=10, TREE__min_samples_split=5;, score=-0.251 total time=   1.1s
# [CV 1/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=5, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=5, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=5, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=5, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=2, TREE__min_samples_leaf=5, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=0.75075, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=0.001, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l2, SVM__C=3.0, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.147 total time=   1.6s
# [CV 2/5] END LR__penalty=l2, SVM__C=3.0, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.112 total time=   1.6s
# [CV 3/5] END LR__penalty=l2, SVM__C=3.0, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.051 total time=   1.0s
# [CV 4/5] END LR__penalty=l2, SVM__C=3.0, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.190 total time=   1.4s
# [CV 5/5] END LR__penalty=l2, SVM__C=3.0, TREE__max_depth=3, TREE__min_samples_leaf=3, TREE__min_samples_split=5;, score=-0.262 total time=   1.1s
# [CV 1/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.127 total time=   1.1s
# [CV 2/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.108 total time=   1.2s
# [CV 3/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.059 total time=   1.1s
# [CV 4/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.176 total time=   1.1s
# [CV 5/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=6, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.224 total time=   1.0s
# [CV 1/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.144 total time=   1.3s
# [CV 2/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.105 total time=   1.4s
# [CV 3/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.049 total time=   1.3s
# [CV 4/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.186 total time=   1.4s
# [CV 5/5] END LR__penalty=l2, SVM__C=2.25025, TREE__max_depth=2, TREE__min_samples_leaf=7, TREE__min_samples_split=2;, score=-0.249 total time=   0.9s
# [CV 1/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.122 total time=   0.7s
# [CV 2/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.108 total time=   0.8s
# [CV 3/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.062 total time=   1.1s
# [CV 4/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.172 total time=   1.1s
# [CV 5/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=4, TREE__min_samples_leaf=15, TREE__min_samples_split=2;, score=-0.227 total time=   1.0s
# [CV 1/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.155 total time=   0.9s
# [CV 2/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.114 total time=   1.0s
# [CV 3/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.054 total time=   1.0s
# [CV 4/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.192 total time=   0.9s
# [CV 5/5] END LR__penalty=l2, SVM__C=0.75075, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=10;, score=-0.225 total time=   0.9s
# [CV 1/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.149 total time=   1.1s
# [CV 2/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.128 total time=   1.2s
# [CV 3/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.063 total time=   1.1s
# [CV 4/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.187 total time=   1.2s
# [CV 5/5] END LR__penalty=None, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=5, TREE__min_samples_split=10;, score=-0.209 total time=   1.0s
# [CV 1/5] END LR__penalty=l1, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=1.5005, TREE__max_depth=5, TREE__min_samples_leaf=7, TREE__min_samples_split=5;, score=nan total time=   0.0s
# [CV 1/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 2/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 3/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 4/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=nan total time=   0.0s
# [CV 5/5] END LR__penalty=l1, SVM__C=3.0, TREE__max_depth=None, TREE__min_samples_leaf=1, TREE__min_samples_split=2;, score=nan total time=   0.0s
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 70 fits failed out of a total of 250.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 70 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_stacking.py", line 658, in fit
#     return super().fit(X, y_encoded, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_stacking.py", line 206, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 127, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py", line 36, in _fit_single_estimator
#     estimator.fit(X, y)
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [-0.15860522 -0.15717595 -0.1415728          nan         nan -0.1534059
#          nan -0.15038814         nan         nan -0.15335886 -0.1582668
#  -0.15277473 -0.14040926         nan         nan -0.14154308         nan
#  -0.14633506 -0.15099032 -0.13839264 -0.14523879         nan -0.14422544
#  -0.15299474 -0.15097762 -0.15174293 -0.14277864 -0.15425966 -0.14728957
#  -0.14299573 -0.1415728  -0.14722531 -0.14826915 -0.14965621 -0.15860522
#  -0.14379161 -0.15660076 -0.14481219         nan         nan         nan
#  -0.15235489 -0.1386804  -0.14646981 -0.13839264 -0.1480509  -0.14718807
#          nan         nan]
#   warnings.warn(
# {'TREE__min_samples_split': 5, 'TREE__min_samples_leaf': 15, 'TREE__max_depth': 4, 'SVM__C': 1.5005, 'LR__penalty': None}
# -0.13839263775451607

# %%
print(stack.get_params())
