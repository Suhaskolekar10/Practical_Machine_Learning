# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold,GridSearchCV,train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import log_loss,accuracy_score,r2_score
from sklearn.ensemble import BaggingClassifier

# %%
image= pd.read_csv("Image_Segmention.csv")
lbl = LabelEncoder()
image['Class'] = lbl.fit_transform(image['Class'])
print(lbl.classes_)
X = image.drop('Class', axis=1)
y =image['Class']
# Out:
# ['BRICKFACE' 'CEMENT' 'FOLIAGE' 'GRASS' 'PATH' 'SKY' 'WINDOW']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=23,stratify=y)

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred_prob=lr.predict_proba(X_test)
lr_11=log_loss(y_test,y_pred_prob)
print('Alone Logistic=',lr_11)
# Out:
# Alone Logistic= 0.27163401168459117
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#########################  BAGGING   ######################################
bagg=BaggingClassifier(lr,n_estimators=15)
bagg.fit(X_train,y_train)
y_pred_probb=bagg.predict_proba(X_test)
bag_11=log_loss(y_test,y_pred_probb)
print('Bagging=',bag_11)
# Out:
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
#########################  SVM LINEAR   ######################################
from sklearn.svm import SVC
svm=SVC(kernel='linear',probability=True,random_state=23)
svm.fit(X_train,y_train)
y_pred_prob2=svm.predict_proba(X_test)
svm_11=log_loss(y_test,y_pred_prob2)
print('Alone SVM=',svm_11)
# Out:
# Alone SVM= 0.6319696534871744

# %%
#########################  SVM RBBF  ######################################
from sklearn.svm import SVC
svm=SVC(kernel='rbf',probability=True,random_state=23)
svm.fit(X_train,y_train)
y_pred_prob2=svm.predict_proba(X_test)
svm_11=log_loss(y_test,y_pred_prob2)
print('Alone SVM=',svm_11)
# Out:
# Alone SVM= 0.734142322193913

# %%
#####################   Griid Search CV -Models  #############################
from sklearn.tree import DecisionTreeClassifier
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
lr=LogisticRegression()
svm=SVC(kernel='linear',probability=True,random_state=23)
dtc=DecisionTreeClassifier(random_state=23)
bagg=BaggingClassifier(random_state=23)
print(bagg.get_params())
params={'estimator':[lr,svm,dtc],
       'n_estimators':[10,15,30,40,50]}
gcv=GridSearchCV(bagg,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3,n_jobs=-1)
gcv.fit(X,y)
# Out:
# {'base_estimator': 'deprecated', 'bootstrap': True, 'bootstrap_features': False, 'estimator': None, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 10, 'n_jobs': None, 'oob_score': False, 'random_state': 23, 'verbose': 0, 'warm_start': False}
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/dai/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'estimator': LogisticRegression(), 'n_estimators': 30}
# -0.5149106073512556
# [CV 4/5] END estimator=LogisticRegression(), n_estimators=10;, score=-0.631 total time=   1.1s
# [CV 1/5] END estimator=SVC(kernel='linear', probability=True, random_state=23), n_estimators=10;, score=-0.599 total time=   3.3s
# [CV 5/5] END estimator=SVC(kernel='linear', probability=True, random_state=23), n_estimators=50;, score=-0.626 total time=   7.0s
# [CV 5/5] END estimator=LogisticRegression(), n_estimators=30;, score=-0.285 total time=   2.1s
# [CV 2/5] END estimator=SVC(kernel='linear', probability=True, random_state=23), n_estimators=15;, score=-0.622 total time=   3.4s
# [CV 4/5] END estimator=LogisticRegression(), n_estimators=10;, score=-0.759 total time=   0.7s
# [CV 3/5] END estimator=LogisticRegression(), n_estimators=40;, score=-0.987 total time=   2.7s
# [CV 5/5] END estimator=SVC(kernel='linear', probability=True, random_state=23), n_estimators=15;, score=-0.638 total time=   4.1s
# ...
