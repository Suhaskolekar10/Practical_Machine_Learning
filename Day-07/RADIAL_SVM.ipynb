# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, GridSearchCV
import numpy as np 
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, log_loss

Image = pd.read_csv("Image_Segmention.csv")
lbl = LabelEncoder()
Image['Class'] = lbl.fit_transform(Image['Class'])

# %%
X = Image.drop('Class', axis=1)
y =Image['Class']
svm = SVC(kernel='linear',probability=True, random_state=23)
svm.fit(X, y)
# Out:
# SVC(kernel='linear', probability=True, random_state=23)

# %%
################### Linear SVM ##########################
kfold = StratifiedKFold(n_splits=5, shuffle=True,random_state=23)
params = {'C': np.linspace(0.001, 5, 10),'decision_function_shape':["ovo","ovr"],
         'gamma':np.linspace(0.001,5,10),'kernel':['linear','rbf']}
gcv = GridSearchCV(svm, param_grid=params,cv=kfold, scoring='neg_log_loss',verbose=3)
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 400 candidates, totalling 2000 fits
# [CV 1/5] END C=0.001, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=-0.453 total time=   0.0s
# [CV 2/5] END C=0.001, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=-0.469 total time=   0.0s
# [CV 3/5] END C=0.001, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=-0.607 total time=   0.0s
# [CV 4/5] END C=0.001, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=-0.596 total time=   0.0s
# [CV 5/5] END C=0.001, decision_function_shape=ovo, gamma=0.001, kernel=linear;, score=-0.487 total time=   0.0s
# [CV 1/5] END C=0.001, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=-1.961 total time=   0.0s
# [CV 2/5] END C=0.001, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=-1.961 total time=   0.0s
# [CV 3/5] END C=0.001, decision_function_shape=ovo, gamma=0.001, kernel=rbf;, score=-1.961 total time=   0.0s
# ...

# %%
#RADIAL SVM
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
svm=SVC(kernel='rbf',probability=True,random_state=23)
svm.fit(X, y)
params={'C':np.linspace(0.001,5,10),'gamma':np.linspace(0.001,5,10),'decision_function_shape':["ovo","ovr"]}
gcv=GridSearchCV(svm,param_grid=params,cv=kfold,scoring="neg_log_loss",verbose=3)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV 1/5] END C=0.001, decision_function_shape=ovo, gamma=0.001;, score=-1.961 total time=   0.0s
# [CV 2/5] END C=0.001, decision_function_shape=ovo, gamma=0.001;, score=-1.961 total time=   0.0s
# [CV 3/5] END C=0.001, decision_function_shape=ovo, gamma=0.001;, score=-1.961 total time=   0.0s
# [CV 4/5] END C=0.001, decision_function_shape=ovo, gamma=0.001;, score=-1.961 total time=   0.0s
# [CV 5/5] END C=0.001, decision_function_shape=ovo, gamma=0.001;, score=-1.946 total time=   0.0s
# [CV 1/5] END C=0.001, decision_function_shape=ovo, gamma=0.5564444444444444;, score=-1.960 total time=   0.0s
# [CV 2/5] END C=0.001, decision_function_shape=ovo, gamma=0.5564444444444444;, score=-1.960 total time=   0.0s
# [CV 3/5] END C=0.001, decision_function_shape=ovo, gamma=0.5564444444444444;, score=-1.960 total time=   0.0s
# ...

# %%
X = Image.drop('Class', axis=1)
y =Image['Class']

svm = SVC(kernel='linear',probability=True, random_state=23)
svm.fit(X, y)

#With Pipeline #Comparison between StadardScaler and MinMaxScaler and getting the max values
from sklearn.model_selection import KFold,GridSearchCV
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler,MinMaxScaler 
from sklearn.pipeline import Pipeline

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
scalar=StandardScaler()
svm=SVC(kernel='linear',probability=True,random_state=23)

pipe=Pipeline([("SCL",scalar),("SVM",svm)])          #here we are using values of KNN transformer
params={'SVM__C': np.linspace(0.001, 5, 10),'SVM__decision_function_shape':["ovo","ovr"],
        'SVM__gamma':list(np.linspace(0.001,5,10))+['scale','auto'],'SVM__kernel':['linear','rbf']}

#log_loss ,MinMaxScaler()
gcv=GridSearchCV(pipe,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001, SVM__kernel=linear;, score=-1.753 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001, SVM__kernel=linear;, score=-1.762 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001, SVM__kernel=linear;, score=-1.761 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001, SVM__kernel=linear;, score=-1.754 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001, SVM__kernel=linear;, score=-1.747 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001, SVM__kernel=rbf;, score=-1.961 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001, SVM__kernel=rbf;, score=-1.961 total time=   0.0s
# ...

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
scalar=MinMaxScaler()

svm=SVC(kernel='linear',probability=True,random_state=23)
svm.fit(X, y)
pipe=Pipeline([("SCL",scalar),("SVM",svm)])          #here we are using values of KNN transformer
params={'SVM__C': np.linspace(0.001, 5, 10),'SVM__decision_function_shape':["ovo","ovr"],
        'SVM__gamma':list(np.linspace(0.001,5,10))+['scale','auto'],'SVM__kernel':['linear','rbf']}

#log_loss ,MinMaxScaler()
gcv=GridSearchCV(pipe,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
#   Cell In[7], line 14
#     print(gcv.best_score_)4
#                           ^
# SyntaxError: invalid syntax

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
scalar=StandardScaler()
svm=SVC(kernel='rbf',probability=True,random_state=23)
svm.fit(X, y)
pipe=Pipeline([("SCL",scalar),("SVM",svm)])          #here we are using values of KNN transformer
params={'SVM__C': np.linspace(0.001, 5, 10),'SVM__decision_function_shape':["ovo","ovr"],
        'SVM__gamma':list(np.linspace(0.001,5,10))+['scale','auto'],'SVM__kernel':['linear','rbf']}

#log_loss ,MinMaxScaler()
gcv=GridSearchCV(pipe,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
scalar=MinMaxScaler()

svm=SVC(kernel='rbf',probability=True,random_state=23)
svm.fit(X, y)
pipe=Pipeline([("SCL",scalar),("SVM",svm)])          #here we are using values of KNN transformer
params={'SVM__C': np.linspace(0.001, 5, 10),'SVM__decision_function_shape':["ovo","ovr"],
        'SVM__gamma':list(np.linspace(0.001,5,10))+['scale','auto'],'SVM__kernel':['linear','rbf']}

#log_loss ,MinMaxScaler()
gcv=GridSearchCV(pipe,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=23)
scalar=MinMaxScaler()

svm=SVC(kernel='rbf',probability=True,random_state=23)
svm.fit(X, y)
pipe=Pipeline([("SCL",scalar),("SVM",svm)])          #here we are using values of KNN transformer
params={'SCL':[StandardScaler(),MinMaxScaler()],'SVM__C': np.linspace(0.001, 5, 10),'SVM__decision_function_shape':["ovo","ovr"],
        'SVM__gamma':list(np.linspace(0.001,5,10))+['scale','auto'],'SVM__kernel':['linear','rbf']}

#log_loss ,MinMaxScaler()
gcv=GridSearchCV(pipe,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)
