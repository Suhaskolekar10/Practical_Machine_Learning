# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /home/dai/anaconda3/lib/python3.11/site-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /home/dai/anaconda3/lib/python3.11/site-packages (from scikit-surprise) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/dai/anaconda3/lib/python3.11/site-packages (from scikit-surprise) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /home/dai/anaconda3/lib/python3.11/site-packages (from scikit-surprise) (1.11.3)

# %%
import surprise
import pandas as pd
import numpy as np
import os

# %%
ratings =pd.read_csv('u.data',sep='\t',names = ['uid','iid','rating','timestamp'])
ratings.drop(columns=['timestamp'],axis=1,inplace = True)

# %%
ratings
# Out:
#        uid   iid  rating
# 0      196   242       3
# 1      186   302       3
# 2       22   377       1
# 3      244    51       2
# 4      166   346       1
# ...    ...   ...     ...
# 99995  880   476       3
# 99996  716   204       5
# 99997  276  1090       1
# 99998   13   225       2
# 99999   12   203       3
#
# [100000 rows x 3 columns]

# %%
lowest_rating = ratings['rating'].min()
highest_rating = ratings['rating'].max()
print("rating ranges between {0} and {1}" .format(lowest_rating, highest_rating))
# Out:
# rating ranges between 1 and 5

# %%
reader = surprise.Reader(rating_scale= (lowest_rating,highest_rating))
data = surprise.Dataset.load_from_df(ratings,reader)
type(data)
# Out:
# surprise.dataset.DatasetAutoFolds

# %%
similarity_options = {'name':'cosine','user_based': True}
#Default k=40
algo = surprise.KNNBasic(sim_options=similarity_options)
output = algo.fit(data.build_full_trainset())
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# # Expected rating for user 50 for item 217

# %%
pred = algo.predict(uid='100', iid='217')
print(pred.est)
# Out:
# 3.52986

# %%
pred
# Out:
# Prediction(uid='100', iid='217', r_ui=None, est=3.52986, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'})

# %%
#Total items
iids =ratings['iid'].unique()
print(iids)
# Out:
# [ 242  302  377 ... 1637 1630 1641]

# %%
# items rated by UID 50
u_iid =ratings[ratings['uid']==100]['iid'].unique()
print(u_iid)
# Out:
# [ 344  354  268  321  355  750  266  288  302  340  689  905  289  691
#   316 1236  342  990  333  752  323  348  313  292 1238  879  300  328
#  1235 1237  678  286  908  690  874  880  349  310  347 1234  270 1233
#   326  269  258  900  886  294  272  881  895  892  887  885  346  751
#   271  898  315]

# %%
iids_to_predict  = np.setdiff1d(iids, u_iid)    #Not rated by UID 50
print(iids_to_predict)
# Out:
# [   1    2    3 ... 1680 1681 1682]

# %%
len(iids_to_predict)
# Out:
# 1623

# %%
#Extracting the estimated ratings from iids_to_predict
testset = [[100,iid,0.] for iid in iids_to_predict]
testset
# Out:
# [[100, 1, 0.0],
#  [100, 2, 0.0],
#  [100, 3, 0.0],
#  [100, 4, 0.0],
#  [100, 5, 0.0],
#  [100, 6, 0.0],
#  [100, 7, 0.0],
#  [100, 8, 0.0],
#  [100, 9, 0.0],
#  [100, 10, 0.0],
#  [100, 11, 0.0],
#  [100, 12, 0.0],
#  [100, 13, 0.0],
#  [100, 14, 0.0],
#  [100, 15, 0.0],
#  [100, 16, 0.0],
#  [100, 17, 0.0],
#  [100, 18, 0.0],
#  [100, 19, 0.0],
#  [100, 20, 0.0],
#  [100, 21, 0.0],
#  [100, 22, 0.0],
#  [100, 23, 0.0],
#  [100, 24, 0.0],
#  [100, 25, 0.0],
#  [100, 26, 0.0],
#  [100, 27, 0.0],
#  [100, 28, 0.0],
#  [100, 29, 0.0],
#  [100, 30, 0.0],
#  [100, 31, 0.0],
#  [100, 32, 0.0],
#  [100, 33, 0.0],
#  [100, 34, 0.0],
#  [100, 35, 0.0],
#  [100, 36, 0.0],
#  [100, 37, 0.0],
#  [100, 38, 0.0],
#  [100, 39, 0.0],
#  [100, 40, 0.0],
#  [100, 41, 0.0],
#  [100, 42, 0.0],
#  [100, 43, 0.0],
#  [100, 44, 0.0],
#  [100, 45, 0.0],
#  [100, 46, 0.0],
#  [100, 47, 0.0],
#  [100, 48, 0.0],
#  [100, 49, 0.0],
#  [100, 50, 0.0],
#  [100, 51, 0.0],
#  [100, 52, 0.0],
#  [100, 53, 0.0],
#  [100, 54, 0.0],
#  [100, 55, 0.0],
#  [100, 56, 0.0],
#  [100, 57, 0.0],
#  [100, 58, 0.0],
#  [100, 59, 0.0],
#  [100, 60, 0.0],
#  [100, 61, 0.0],
#  [100, 62, 0.0],
#  [100, 63, 0.0],
#  [100, 64, 0.0],
#  [100, 65, 0.0],
#  [100, 66, 0.0],
#  [100, 67, 0.0],
#  [100, 68, 0.0],
#  [100, 69, 0.0],
#  [100, 70, 0.0],
#  [100, 71, 0.0],
#  [100, 72, 0.0],
#  [100, 73, 0.0],
#  [100, 74, 0.0],
#  [100, 75, 0.0],
#  [100, 76, 0.0],
#  [100, 77, 0.0],
#  [100, 78, 0.0],
#  [100, 79, 0.0],
#  [100, 80, 0.0],
#  [100, 81, 0.0],
#  [100, 82, 0.0],
#  [100, 83, 0.0],
#  [100, 84, 0.0],
#  [100, 85, 0.0],
#  [100, 86, 0.0],
#  [100, 87, 0.0],
#  [100, 88, 0.0],
#  [100, 89, 0.0],
#  [100, 90, 0.0],
#  [100, 91, 0.0],
#  [100, 92, 0.0],
#  [100, 93, 0.0],
#  [100, 94, 0.0],
#  [100, 95, 0.0],
#  [100, 96, 0.0],
#  [100, 97, 0.0],
#  [100, 98, 0.0],
#  [100, 99, 0.0],
#  [100, 100, 0.0],
#  [100, 101, 0.0],
#  [100, 102, 0.0],
#  [100, 103, 0.0],
#  [100, 104, 0.0],
#  [100, 105, 0.0],
#  [100, 106, 0.0],
#  [100, 107, 0.0],
#  [100, 108, 0.0],
#  [100, 109, 0.0],
#  [100, 110, 0.0],
#  [100, 111, 0.0],
#  [100, 112, 0.0],
#  [100, 113, 0.0],
#  [100, 114, 0.0],
#  [100, 115, 0.0],
#  [100, 116, 0.0],
#  [100, 117, 0.0],
#  [100, 118, 0.0],
#  [100, 119, 0.0],
#  [100, 120, 0.0],
#  [100, 121, 0.0],
#  [100, 122, 0.0],
#  [100, 123, 0.0],
#  [100, 124, 0.0],
#  [100, 125, 0.0],
#  [100, 126, 0.0],
#  [100, 127, 0.0],
#  [100, 128, 0.0],
#  [100, 129, 0.0],
#  [100, 130, 0.0],
#  [100, 131, 0.0],
#  [100, 132, 0.0],
#  [100, 133, 0.0],
#  [100, 134, 0.0],
#  [100, 135, 0.0],
#  [100, 136, 0.0],
#  [100, 137, 0.0],
#  [100, 138, 0.0],
#  [100, 139, 0.0],
#  [100, 140, 0.0],
#  [100, 141, 0.0],
#  [100, 142, 0.0],
#  [100, 143, 0.0],
#  [100, 144, 0.0],
#  [100, 145, 0.0],
#  [100, 146, 0.0],
#  [100, 147, 0.0],
#  [100, 148, 0.0],
#  [100, 149, 0.0],
#  [100, 150, 0.0],
#  [100, 151, 0.0],
#  [100, 152, 0.0],
#  [100, 153, 0.0],
#  [100, 154, 0.0],
#  [100, 155, 0.0],
#  [100, 156, 0.0],
#  [100, 157, 0.0],
#  [100, 158, 0.0],
#  [100, 159, 0.0],
#  [100, 160, 0.0],
#  [100, 161, 0.0],
#  [100, 162, 0.0],
#  [100, 163, 0.0],
#  [100, 164, 0.0],
#  [100, 165, 0.0],
#  [100, 166, 0.0],
#  [100, 167, 0.0],
#  [100, 168, 0.0],
#  [100, 169, 0.0],
#  [100, 170, 0.0],
#  [100, 171, 0.0],
#  [100, 172, 0.0],
#  [100, 173, 0.0],
#  [100, 174, 0.0],
#  [100, 175, 0.0],
#  [100, 176, 0.0],
#  [100, 177, 0.0],
#  [100, 178, 0.0],
#  [100, 179, 0.0],
#  [100, 180, 0.0],
#  [100, 181, 0.0],
#  [100, 182, 0.0],
#  [100, 183, 0.0],
#  [100, 184, 0.0],
#  [100, 185, 0.0],
#  [100, 186, 0.0],
#  [100, 187, 0.0],
#  [100, 188, 0.0],
#  [100, 189, 0.0],
#  [100, 190, 0.0],
#  [100, 191, 0.0],
#  [100, 192, 0.0],
#  [100, 193, 0.0],
#  [100, 194, 0.0],
#  [100, 195, 0.0],
#  [100, 196, 0.0],
#  [100, 197, 0.0],
#  [100, 198, 0.0],
#  [100, 199, 0.0],
#  [100, 200, 0.0],
#  [100, 201, 0.0],
#  [100, 202, 0.0],
#  [100, 203, 0.0],
#  [100, 204, 0.0],
#  [100, 205, 0.0],
#  [100, 206, 0.0],
#  [100, 207, 0.0],
#  [100, 208, 0.0],
#  [100, 209, 0.0],
#  [100, 210, 0.0],
#  [100, 211, 0.0],
#  [100, 212, 0.0],
#  [100, 213, 0.0],
#  [100, 214, 0.0],
#  [100, 215, 0.0],
#  [100, 216, 0.0],
#  [100, 217, 0.0],
#  [100, 218, 0.0],
#  [100, 219, 0.0],
#  [100, 220, 0.0],
#  [100, 221, 0.0],
#  [100, 222, 0.0],
#  [100, 223, 0.0],
#  [100, 224, 0.0],
#  [100, 225, 0.0],
#  [100, 226, 0.0],
#  [100, 227, 0.0],
#  [100, 228, 0.0],
#  [100, 229, 0.0],
#  [100, 230, 0.0],
#  [100, 231, 0.0],
#  [100, 232, 0.0],
#  [100, 233, 0.0],
#  [100, 234, 0.0],
#  [100, 235, 0.0],
#  [100, 236, 0.0],
#  [100, 237, 0.0],
#  [100, 238, 0.0],
#  [100, 239, 0.0],
#  [100, 240, 0.0],
#  [100, 241, 0.0],
#  [100, 242, 0.0],
#  [100, 243, 0.0],
#  [100, 244, 0.0],
#  [100, 245, 0.0],
#  [100, 246, 0.0],
#  [100, 247, 0.0],
#  [100, 248, 0.0],
#  [100, 249, 0.0],
#  [100, 250, 0.0],
#  [100, 251, 0.0],
#  [100, 252, 0.0],
#  [100, 253, 0.0],
#  [100, 254, 0.0],
#  [100, 255, 0.0],
#  [100, 256, 0.0],
#  [100, 257, 0.0],
#  [100, 259, 0.0],
#  [100, 260, 0.0],
#  [100, 261, 0.0],
#  [100, 262, 0.0],
#  [100, 263, 0.0],
#  [100, 264, 0.0],
#  [100, 265, 0.0],
#  [100, 267, 0.0],
#  [100, 273, 0.0],
#  [100, 274, 0.0],
#  [100, 275, 0.0],
#  [100, 276, 0.0],
#  [100, 277, 0.0],
#  [100, 278, 0.0],
#  [100, 279, 0.0],
#  [100, 280, 0.0],
#  [100, 281, 0.0],
#  [100, 282, 0.0],
#  [100, 283, 0.0],
#  [100, 284, 0.0],
#  [100, 285, 0.0],
#  [100, 287, 0.0],
#  [100, 290, 0.0],
#  [100, 291, 0.0],
#  [100, 293, 0.0],
#  [100, 295, 0.0],
#  [100, 296, 0.0],
#  [100, 297, 0.0],
#  [100, 298, 0.0],
#  [100, 299, 0.0],
#  [100, 301, 0.0],
#  [100, 303, 0.0],
#  [100, 304, 0.0],
#  [100, 305, 0.0],
#  [100, 306, 0.0],
#  [100, 307, 0.0],
#  [100, 308, 0.0],
#  [100, 309, 0.0],
#  [100, 311, 0.0],
#  [100, 312, 0.0],
#  [100, 314, 0.0],
#  [100, 317, 0.0],
#  [100, 318, 0.0],
#  [100, 319, 0.0],
#  [100, 320, 0.0],
#  [100, 322, 0.0],
#  [100, 324, 0.0],
#  [100, 325, 0.0],
#  [100, 327, 0.0],
#  [100, 329, 0.0],
#  [100, 330, 0.0],
#  [100, 331, 0.0],
#  [100, 332, 0.0],
#  [100, 334, 0.0],
#  [100, 335, 0.0],
#  [100, 336, 0.0],
#  [100, 337, 0.0],
#  [100, 338, 0.0],
#  [100, 339, 0.0],
#  [100, 341, 0.0],
#  [100, 343, 0.0],
#  [100, 345, 0.0],
#  [100, 350, 0.0],
#  [100, 351, 0.0],
#  [100, 352, 0.0],
#  [100, 353, 0.0],
#  [100, 356, 0.0],
#  [100, 357, 0.0],
#  [100, 358, 0.0],
#  [100, 359, 0.0],
#  [100, 360, 0.0],
#  [100, 361, 0.0],
#  [100, 362, 0.0],
#  [100, 363, 0.0],
#  [100, 364, 0.0],
#  [100, 365, 0.0],
#  [100, 366, 0.0],
#  [100, 367, 0.0],
#  [100, 368, 0.0],
#  [100, 369, 0.0],
#  [100, 370, 0.0],
#  [100, 371, 0.0],
#  [100, 372, 0.0],
#  [100, 373, 0.0],
#  [100, 374, 0.0],
#  [100, 375, 0.0],
#  [100, 376, 0.0],
#  [100, 377, 0.0],
#  [100, 378, 0.0],
#  [100, 379, 0.0],
#  [100, 380, 0.0],
#  [100, 381, 0.0],
#  [100, 382, 0.0],
#  [100, 383, 0.0],
#  [100, 384, 0.0],
#  [100, 385, 0.0],
#  [100, 386, 0.0],
#  [100, 387, 0.0],
#  [100, 388, 0.0],
#  [100, 389, 0.0],
#  [100, 390, 0.0],
#  [100, 391, 0.0],
#  [100, 392, 0.0],
#  [100, 393, 0.0],
#  [100, 394, 0.0],
#  [100, 395, 0.0],
#  [100, 396, 0.0],
#  [100, 397, 0.0],
#  [100, 398, 0.0],
#  [100, 399, 0.0],
#  [100, 400, 0.0],
#  [100, 401, 0.0],
#  [100, 402, 0.0],
#  [100, 403, 0.0],
#  [100, 404, 0.0],
#  [100, 405, 0.0],
#  [100, 406, 0.0],
#  [100, 407, 0.0],
#  [100, 408, 0.0],
#  [100, 409, 0.0],
#  [100, 410, 0.0],
#  [100, 411, 0.0],
#  [100, 412, 0.0],
#  [100, 413, 0.0],
#  [100, 414, 0.0],
#  [100, 415, 0.0],
#  [100, 416, 0.0],
#  [100, 417, 0.0],
#  [100, 418, 0.0],
#  [100, 419, 0.0],
#  [100, 420, 0.0],
#  [100, 421, 0.0],
#  [100, 422, 0.0],
#  [100, 423, 0.0],
#  [100, 424, 0.0],
#  [100, 425, 0.0],
#  [100, 426, 0.0],
#  [100, 427, 0.0],
#  [100, 428, 0.0],
#  [100, 429, 0.0],
#  [100, 430, 0.0],
#  [100, 431, 0.0],
#  [100, 432, 0.0],
#  [100, 433, 0.0],
#  [100, 434, 0.0],
#  [100, 435, 0.0],
#  [100, 436, 0.0],
#  [100, 437, 0.0],
#  [100, 438, 0.0],
#  [100, 439, 0.0],
#  [100, 440, 0.0],
#  [100, 441, 0.0],
#  [100, 442, 0.0],
#  [100, 443, 0.0],
#  [100, 444, 0.0],
#  [100, 445, 0.0],
#  [100, 446, 0.0],
#  [100, 447, 0.0],
#  [100, 448, 0.0],
#  [100, 449, 0.0],
#  [100, 450, 0.0],
#  [100, 451, 0.0],
#  [100, 452, 0.0],
#  [100, 453, 0.0],
#  [100, 454, 0.0],
#  [100, 455, 0.0],
#  [100, 456, 0.0],
#  [100, 457, 0.0],
#  [100, 458, 0.0],
#  [100, 459, 0.0],
#  [100, 460, 0.0],
#  [100, 461, 0.0],
#  [100, 462, 0.0],
#  [100, 463, 0.0],
#  [100, 464, 0.0],
#  [100, 465, 0.0],
#  [100, 466, 0.0],
#  [100, 467, 0.0],
#  [100, 468, 0.0],
#  [100, 469, 0.0],
#  [100, 470, 0.0],
#  [100, 471, 0.0],
#  [100, 472, 0.0],
#  [100, 473, 0.0],
#  [100, 474, 0.0],
#  [100, 475, 0.0],
#  [100, 476, 0.0],
#  [100, 477, 0.0],
#  [100, 478, 0.0],
#  [100, 479, 0.0],
#  [100, 480, 0.0],
#  [100, 481, 0.0],
#  [100, 482, 0.0],
#  [100, 483, 0.0],
#  [100, 484, 0.0],
#  [100, 485, 0.0],
#  [100, 486, 0.0],
#  [100, 487, 0.0],
#  [100, 488, 0.0],
#  [100, 489, 0.0],
#  [100, 490, 0.0],
#  [100, 491, 0.0],
#  [100, 492, 0.0],
#  [100, 493, 0.0],
#  [100, 494, 0.0],
#  [100, 495, 0.0],
#  [100, 496, 0.0],
#  [100, 497, 0.0],
#  [100, 498, 0.0],
#  [100, 499, 0.0],
#  [100, 500, 0.0],
#  [100, 501, 0.0],
#  [100, 502, 0.0],
#  [100, 503, 0.0],
#  [100, 504, 0.0],
#  [100, 505, 0.0],
#  [100, 506, 0.0],
#  [100, 507, 0.0],
#  [100, 508, 0.0],
#  [100, 509, 0.0],
#  [100, 510, 0.0],
#  [100, 511, 0.0],
#  [100, 512, 0.0],
#  [100, 513, 0.0],
#  [100, 514, 0.0],
#  [100, 515, 0.0],
#  [100, 516, 0.0],
#  [100, 517, 0.0],
#  [100, 518, 0.0],
#  [100, 519, 0.0],
#  [100, 520, 0.0],
#  [100, 521, 0.0],
#  [100, 522, 0.0],
#  [100, 523, 0.0],
#  [100, 524, 0.0],
#  [100, 525, 0.0],
#  [100, 526, 0.0],
#  [100, 527, 0.0],
#  [100, 528, 0.0],
#  [100, 529, 0.0],
#  [100, 530, 0.0],
#  [100, 531, 0.0],
#  [100, 532, 0.0],
#  [100, 533, 0.0],
#  [100, 534, 0.0],
#  [100, 535, 0.0],
#  [100, 536, 0.0],
#  [100, 537, 0.0],
#  [100, 538, 0.0],
#  [100, 539, 0.0],
#  [100, 540, 0.0],
#  [100, 541, 0.0],
#  [100, 542, 0.0],
#  [100, 543, 0.0],
#  [100, 544, 0.0],
#  [100, 545, 0.0],
#  [100, 546, 0.0],
#  [100, 547, 0.0],
#  [100, 548, 0.0],
#  [100, 549, 0.0],
#  [100, 550, 0.0],
#  [100, 551, 0.0],
#  [100, 552, 0.0],
#  [100, 553, 0.0],
#  [100, 554, 0.0],
#  [100, 555, 0.0],
#  [100, 556, 0.0],
#  [100, 557, 0.0],
#  [100, 558, 0.0],
#  [100, 559, 0.0],
#  [100, 560, 0.0],
#  [100, 561, 0.0],
#  [100, 562, 0.0],
#  [100, 563, 0.0],
#  [100, 564, 0.0],
#  [100, 565, 0.0],
#  [100, 566, 0.0],
#  [100, 567, 0.0],
#  [100, 568, 0.0],
#  [100, 569, 0.0],
#  [100, 570, 0.0],
#  [100, 571, 0.0],
#  [100, 572, 0.0],
#  [100, 573, 0.0],
#  [100, 574, 0.0],
#  [100, 575, 0.0],
#  [100, 576, 0.0],
#  [100, 577, 0.0],
#  [100, 578, 0.0],
#  [100, 579, 0.0],
#  [100, 580, 0.0],
#  [100, 581, 0.0],
#  [100, 582, 0.0],
#  [100, 583, 0.0],
#  [100, 584, 0.0],
#  [100, 585, 0.0],
#  [100, 586, 0.0],
#  [100, 587, 0.0],
#  [100, 588, 0.0],
#  [100, 589, 0.0],
#  [100, 590, 0.0],
#  [100, 591, 0.0],
#  [100, 592, 0.0],
#  [100, 593, 0.0],
#  [100, 594, 0.0],
#  [100, 595, 0.0],
#  [100, 596, 0.0],
#  [100, 597, 0.0],
#  [100, 598, 0.0],
#  [100, 599, 0.0],
#  [100, 600, 0.0],
#  [100, 601, 0.0],
#  [100, 602, 0.0],
#  [100, 603, 0.0],
#  [100, 604, 0.0],
#  [100, 605, 0.0],
#  [100, 606, 0.0],
#  [100, 607, 0.0],
#  [100, 608, 0.0],
#  [100, 609, 0.0],
#  [100, 610, 0.0],
#  [100, 611, 0.0],
#  [100, 612, 0.0],
#  [100, 613, 0.0],
#  [100, 614, 0.0],
#  [100, 615, 0.0],
#  [100, 616, 0.0],
#  [100, 617, 0.0],
#  [100, 618, 0.0],
#  [100, 619, 0.0],
#  [100, 620, 0.0],
#  [100, 621, 0.0],
#  [100, 622, 0.0],
#  [100, 623, 0.0],
#  [100, 624, 0.0],
#  [100, 625, 0.0],
#  [100, 626, 0.0],
#  [100, 627, 0.0],
#  [100, 628, 0.0],
#  [100, 629, 0.0],
#  [100, 630, 0.0],
#  [100, 631, 0.0],
#  [100, 632, 0.0],
#  [100, 633, 0.0],
#  [100, 634, 0.0],
#  [100, 635, 0.0],
#  [100, 636, 0.0],
#  [100, 637, 0.0],
#  [100, 638, 0.0],
#  [100, 639, 0.0],
#  [100, 640, 0.0],
#  [100, 641, 0.0],
#  [100, 642, 0.0],
#  [100, 643, 0.0],
#  [100, 644, 0.0],
#  [100, 645, 0.0],
#  [100, 646, 0.0],
#  [100, 647, 0.0],
#  [100, 648, 0.0],
#  [100, 649, 0.0],
#  [100, 650, 0.0],
#  [100, 651, 0.0],
#  [100, 652, 0.0],
#  [100, 653, 0.0],
#  [100, 654, 0.0],
#  [100, 655, 0.0],
#  [100, 656, 0.0],
#  [100, 657, 0.0],
#  [100, 658, 0.0],
#  [100, 659, 0.0],
#  [100, 660, 0.0],
#  [100, 661, 0.0],
#  [100, 662, 0.0],
#  [100, 663, 0.0],
#  [100, 664, 0.0],
#  [100, 665, 0.0],
#  [100, 666, 0.0],
#  [100, 667, 0.0],
#  [100, 668, 0.0],
#  [100, 669, 0.0],
#  [100, 670, 0.0],
#  [100, 671, 0.0],
#  [100, 672, 0.0],
#  [100, 673, 0.0],
#  [100, 674, 0.0],
#  [100, 675, 0.0],
#  [100, 676, 0.0],
#  [100, 677, 0.0],
#  [100, 679, 0.0],
#  [100, 680, 0.0],
#  [100, 681, 0.0],
#  [100, 682, 0.0],
#  [100, 683, 0.0],
#  [100, 684, 0.0],
#  [100, 685, 0.0],
#  [100, 686, 0.0],
#  [100, 687, 0.0],
#  [100, 688, 0.0],
#  [100, 692, 0.0],
#  [100, 693, 0.0],
#  [100, 694, 0.0],
#  [100, 695, 0.0],
#  [100, 696, 0.0],
#  [100, 697, 0.0],
#  [100, 698, 0.0],
#  [100, 699, 0.0],
#  [100, 700, 0.0],
#  [100, 701, 0.0],
#  [100, 702, 0.0],
#  [100, 703, 0.0],
#  [100, 704, 0.0],
#  [100, 705, 0.0],
#  [100, 706, 0.0],
#  [100, 707, 0.0],
#  [100, 708, 0.0],
#  [100, 709, 0.0],
#  [100, 710, 0.0],
#  [100, 711, 0.0],
#  [100, 712, 0.0],
#  [100, 713, 0.0],
#  [100, 714, 0.0],
#  [100, 715, 0.0],
#  [100, 716, 0.0],
#  [100, 717, 0.0],
#  [100, 718, 0.0],
#  [100, 719, 0.0],
#  [100, 720, 0.0],
#  [100, 721, 0.0],
#  [100, 722, 0.0],
#  [100, 723, 0.0],
#  [100, 724, 0.0],
#  [100, 725, 0.0],
#  [100, 726, 0.0],
#  [100, 727, 0.0],
#  [100, 728, 0.0],
#  [100, 729, 0.0],
#  [100, 730, 0.0],
#  [100, 731, 0.0],
#  [100, 732, 0.0],
#  [100, 733, 0.0],
#  [100, 734, 0.0],
#  [100, 735, 0.0],
#  [100, 736, 0.0],
#  [100, 737, 0.0],
#  [100, 738, 0.0],
#  [100, 739, 0.0],
#  [100, 740, 0.0],
#  [100, 741, 0.0],
#  [100, 742, 0.0],
#  [100, 743, 0.0],
#  [100, 744, 0.0],
#  [100, 745, 0.0],
#  [100, 746, 0.0],
#  [100, 747, 0.0],
#  [100, 748, 0.0],
#  [100, 749, 0.0],
#  [100, 753, 0.0],
#  [100, 754, 0.0],
#  [100, 755, 0.0],
#  [100, 756, 0.0],
#  [100, 757, 0.0],
#  [100, 758, 0.0],
#  [100, 759, 0.0],
#  [100, 760, 0.0],
#  [100, 761, 0.0],
#  [100, 762, 0.0],
#  [100, 763, 0.0],
#  [100, 764, 0.0],
#  [100, 765, 0.0],
#  [100, 766, 0.0],
#  [100, 767, 0.0],
#  [100, 768, 0.0],
#  [100, 769, 0.0],
#  [100, 770, 0.0],
#  [100, 771, 0.0],
#  [100, 772, 0.0],
#  [100, 773, 0.0],
#  [100, 774, 0.0],
#  [100, 775, 0.0],
#  [100, 776, 0.0],
#  [100, 777, 0.0],
#  [100, 778, 0.0],
#  [100, 779, 0.0],
#  [100, 780, 0.0],
#  [100, 781, 0.0],
#  [100, 782, 0.0],
#  [100, 783, 0.0],
#  [100, 784, 0.0],
#  [100, 785, 0.0],
#  [100, 786, 0.0],
#  [100, 787, 0.0],
#  [100, 788, 0.0],
#  [100, 789, 0.0],
#  [100, 790, 0.0],
#  [100, 791, 0.0],
#  [100, 792, 0.0],
#  [100, 793, 0.0],
#  [100, 794, 0.0],
#  [100, 795, 0.0],
#  [100, 796, 0.0],
#  [100, 797, 0.0],
#  [100, 798, 0.0],
#  [100, 799, 0.0],
#  [100, 800, 0.0],
#  [100, 801, 0.0],
#  [100, 802, 0.0],
#  [100, 803, 0.0],
#  [100, 804, 0.0],
#  [100, 805, 0.0],
#  [100, 806, 0.0],
#  [100, 807, 0.0],
#  [100, 808, 0.0],
#  [100, 809, 0.0],
#  [100, 810, 0.0],
#  [100, 811, 0.0],
#  [100, 812, 0.0],
#  [100, 813, 0.0],
#  [100, 814, 0.0],
#  [100, 815, 0.0],
#  [100, 816, 0.0],
#  [100, 817, 0.0],
#  [100, 818, 0.0],
#  [100, 819, 0.0],
#  [100, 820, 0.0],
#  [100, 821, 0.0],
#  [100, 822, 0.0],
#  [100, 823, 0.0],
#  [100, 824, 0.0],
#  [100, 825, 0.0],
#  [100, 826, 0.0],
#  [100, 827, 0.0],
#  [100, 828, 0.0],
#  [100, 829, 0.0],
#  [100, 830, 0.0],
#  [100, 831, 0.0],
#  [100, 832, 0.0],
#  [100, 833, 0.0],
#  [100, 834, 0.0],
#  [100, 835, 0.0],
#  [100, 836, 0.0],
#  [100, 837, 0.0],
#  [100, 838, 0.0],
#  [100, 839, 0.0],
#  [100, 840, 0.0],
#  [100, 841, 0.0],
#  [100, 842, 0.0],
#  [100, 843, 0.0],
#  [100, 844, 0.0],
#  [100, 845, 0.0],
#  [100, 846, 0.0],
#  [100, 847, 0.0],
#  [100, 848, 0.0],
#  [100, 849, 0.0],
#  [100, 850, 0.0],
#  [100, 851, 0.0],
#  [100, 852, 0.0],
#  [100, 853, 0.0],
#  [100, 854, 0.0],
#  [100, 855, 0.0],
#  [100, 856, 0.0],
#  [100, 857, 0.0],
#  [100, 858, 0.0],
#  [100, 859, 0.0],
#  [100, 860, 0.0],
#  [100, 861, 0.0],
#  [100, 862, 0.0],
#  [100, 863, 0.0],
#  [100, 864, 0.0],
#  [100, 865, 0.0],
#  [100, 866, 0.0],
#  [100, 867, 0.0],
#  [100, 868, 0.0],
#  [100, 869, 0.0],
#  [100, 870, 0.0],
#  [100, 871, 0.0],
#  [100, 872, 0.0],
#  [100, 873, 0.0],
#  [100, 875, 0.0],
#  [100, 876, 0.0],
#  [100, 877, 0.0],
#  [100, 878, 0.0],
#  [100, 882, 0.0],
#  [100, 883, 0.0],
#  [100, 884, 0.0],
#  [100, 888, 0.0],
#  [100, 889, 0.0],
#  [100, 890, 0.0],
#  [100, 891, 0.0],
#  [100, 893, 0.0],
#  [100, 894, 0.0],
#  [100, 896, 0.0],
#  [100, 897, 0.0],
#  [100, 899, 0.0],
#  [100, 901, 0.0],
#  [100, 902, 0.0],
#  [100, 903, 0.0],
#  [100, 904, 0.0],
#  [100, 906, 0.0],
#  [100, 907, 0.0],
#  [100, 909, 0.0],
#  [100, 910, 0.0],
#  [100, 911, 0.0],
#  [100, 912, 0.0],
#  [100, 913, 0.0],
#  [100, 914, 0.0],
#  [100, 915, 0.0],
#  [100, 916, 0.0],
#  [100, 917, 0.0],
#  [100, 918, 0.0],
#  [100, 919, 0.0],
#  [100, 920, 0.0],
#  [100, 921, 0.0],
#  [100, 922, 0.0],
#  [100, 923, 0.0],
#  [100, 924, 0.0],
#  [100, 925, 0.0],
#  [100, 926, 0.0],
#  [100, 927, 0.0],
#  [100, 928, 0.0],
#  [100, 929, 0.0],
#  [100, 930, 0.0],
#  [100, 931, 0.0],
#  [100, 932, 0.0],
#  [100, 933, 0.0],
#  [100, 934, 0.0],
#  [100, 935, 0.0],
#  [100, 936, 0.0],
#  [100, 937, 0.0],
#  [100, 938, 0.0],
#  [100, 939, 0.0],
#  [100, 940, 0.0],
#  [100, 941, 0.0],
#  [100, 942, 0.0],
#  [100, 943, 0.0],
#  [100, 944, 0.0],
#  [100, 945, 0.0],
#  [100, 946, 0.0],
#  [100, 947, 0.0],
#  [100, 948, 0.0],
#  [100, 949, 0.0],
#  [100, 950, 0.0],
#  [100, 951, 0.0],
#  [100, 952, 0.0],
#  [100, 953, 0.0],
#  [100, 954, 0.0],
#  [100, 955, 0.0],
#  [100, 956, 0.0],
#  [100, 957, 0.0],
#  [100, 958, 0.0],
#  [100, 959, 0.0],
#  [100, 960, 0.0],
#  [100, 961, 0.0],
#  [100, 962, 0.0],
#  [100, 963, 0.0],
#  [100, 964, 0.0],
#  [100, 965, 0.0],
#  [100, 966, 0.0],
#  [100, 967, 0.0],
#  [100, 968, 0.0],
#  [100, 969, 0.0],
#  [100, 970, 0.0],
#  [100, 971, 0.0],
#  [100, 972, 0.0],
#  [100, 973, 0.0],
#  [100, 974, 0.0],
#  [100, 975, 0.0],
#  [100, 976, 0.0],
#  [100, 977, 0.0],
#  [100, 978, 0.0],
#  [100, 979, 0.0],
#  [100, 980, 0.0],
#  [100, 981, 0.0],
#  [100, 982, 0.0],
#  [100, 983, 0.0],
#  [100, 984, 0.0],
#  [100, 985, 0.0],
#  [100, 986, 0.0],
#  [100, 987, 0.0],
#  [100, 988, 0.0],
#  [100, 989, 0.0],
#  [100, 991, 0.0],
#  [100, 992, 0.0],
#  [100, 993, 0.0],
#  [100, 994, 0.0],
#  [100, 995, 0.0],
#  [100, 996, 0.0],
#  [100, 997, 0.0],
#  [100, 998, 0.0],
#  [100, 999, 0.0],
#  [100, 1000, 0.0],
#  [100, 1001, 0.0],
#  [100, 1002, 0.0],
#  [100, 1003, 0.0],
#  [100, 1004, 0.0],
#  [100, 1005, 0.0],
#  [100, 1006, 0.0],
#  [100, 1007, 0.0],
#  [100, 1008, 0.0],
#  [100, 1009, 0.0],
#  [100, 1010, 0.0],
#  [100, 1011, 0.0],
#  [100, 1012, 0.0],
#  [100, 1013, 0.0],
#  [100, 1014, 0.0],
#  [100, 1015, 0.0],
#  [100, 1016, 0.0],
#  [100, 1017, 0.0],
#  [100, 1018, 0.0],
#  [100, 1019, 0.0],
#  [100, 1020, 0.0],
#  [100, 1021, 0.0],
#  [100, 1022, 0.0],
#  [100, 1023, 0.0],
#  [100, 1024, 0.0],
#  [100, 1025, 0.0],
#  [100, 1026, 0.0],
#  [100, 1027, 0.0],
#  [100, 1028, 0.0],
#  [100, 1029, 0.0],
#  [100, 1030, 0.0],
#  [100, 1031, 0.0],
#  [100, 1032, 0.0],
#  [100, 1033, 0.0],
#  [100, 1034, 0.0],
#  [100, 1035, 0.0],
#  [100, 1036, 0.0],
#  [100, 1037, 0.0],
#  [100, 1038, 0.0],
#  [100, 1039, 0.0],
#  [100, 1040, 0.0],
#  [100, 1041, 0.0],
#  [100, 1042, 0.0],
#  [100, 1043, 0.0],
#  [100, 1044, 0.0],
#  [100, 1045, 0.0],
#  [100, 1046, 0.0],
#  [100, 1047, 0.0],
#  [100, 1048, 0.0],
#  [100, 1049, 0.0],
#  [100, 1050, 0.0],
#  [100, 1051, 0.0],
#  [100, 1052, 0.0],
#  [100, 1053, 0.0],
#  ...]

# %%
testset = [[100,iid,0.] for iid in iids_to_predict]
predictions = algo.test(testset)
predictions[:5]
# Out:
# [Prediction(uid=100, iid=1, r_ui=0.0, est=4.4499638991027775, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=100, iid=2, r_ui=0.0, est=3.1746676342628377, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=100, iid=3, r_ui=0.0, est=3.223974938384731, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=100, iid=4, r_ui=0.0, est=3.5747654705675784, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid=100, iid=5, r_ui=0.0, est=3.4745866651729056, details={'actual_k': 40, 'was_impossible': False})]

# %%
len(predictions)
# Out:
# 1623

# %%
(predictions[4].iid,predictions[4].est)
# Out:
# (5, 3.4745866651729056)

# %%
# for i in len(predictions):
#     (predictions[i].iid,predictions[i].est)

# %%
pred_ratings=[(predictions[i].iid,predictions[i].est) for i in range(0,len(predictions))]
predicted_rating=pd.DataFrame(pred_ratings,columns=['iid','est_rating'])
exp_ratings=predicted_rating.sort_values(by='est_rating',ascending=False)

# %%
sorted_exp=exp_ratings.sort_values(by=['est_rating','iid'],ascending=[False,True])
sorted_exp.head(10)
# Out:
#        iid  est_rating
# 774    814         5.0
# 1068  1122         5.0
# 1135  1189         5.0
# 1147  1201         5.0
# 1233  1293         5.0
# 1407  1467         5.0
# 1440  1500         5.0
# 1476  1536         5.0
# 1539  1599         5.0
# 1593  1653         5.0

# %% [markdown]
# Tuning for best k

# %%
from surprise.model_selection import GridSearchCV
from surprise.model_selection.split import KFold

# %%
param_grid={'k':[20,30,40,50,60,70],'user_based':[True,False]}
param_grid
# Out:
# {'k': [20, 30, 40, 50, 60, 70], 'user_based': [True, False]}

# %%
kfold=KFold(n_splits=5,random_state=23,shuffle=True)
gs=GridSearchCV(surprise.KNNBasic,param_grid,measures=['rmse','mae'],cv=kfold)

# %%
gs.fit(data)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
gs.best_score['rmse']
# Out:
# 0.9765768260490179

# %%
gs.best_score['mae']
# Out:
# 0.7702810060041623

# %%
print(gs.best_params['rmse'])
# Out:
# {'k': 20, 'user_based': True}

# %%
print(gs.best_params['mae'])
# Out:
# {'k': 20, 'user_based': True}

# %%
gs.best_estimator['rmse']
algo.fit(data.build_full_trainset())
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
gs.best_estimator['mae']
algo.fit(data.build_full_trainset())
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# # ITEM BASED

# %%
param_grid={'k':[20,30,40,50,60,70],'sim_options':{'name':['cosine'],'user_based':[False]}}
param_grid

kfold=KFold(n_splits=5,random_state=23,shuffle=True)
gs=GridSearchCV(surprise.KNNBasic,param_grid,measures=['rmse','mae'],cv=kfold)

# %%
gs.fit(data)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
gs.best_score['rmse']
# Out:
# 1.0240756703702425

# %%
print(gs.best_params['rmse'])
# Out:
# {'k': 60, 'sim_options': {'name': 'cosine', 'user_based': False}}

# %%
gs.best_estimator['rmse']
algo.fit(data.build_full_trainset())
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
movies =pd.read_csv('u.item',sep='|',encoding='latin-1',header=None)
movies=movies.iloc[:,:3]
movies.columns=['iid','movie','release_date']
movies.head()
# Out:
#    iid              movie release_date
# 0    1   Toy Story (1995)  01-Jan-1995
# 1    2   GoldenEye (1995)  01-Jan-1995
# 2    3  Four Rooms (1995)  01-Jan-1995
# 3    4  Get Shorty (1995)  01-Jan-1995
# 4    5     Copycat (1995)  01-Jan-1995

# %%
sorted_exp=sorted_exp.merge(movies,on='iid')
sorted_exp.head(10)
# Out:
#     iid  est_rating                                              movie  \
# 0   814         5.0                      Great Day in Harlem, A (1994)
# 1  1122         5.0                     They Made Me a Criminal (1939)
# 2  1189         5.0                                 Prefontaine (1997)
# 3  1201         5.0         Marlene Dietrich: Shadow and Light (1996)
# 4  1293         5.0                                    Star Kid (1997)
# 5  1467         5.0               Saint of Fort Washington, The (1993)
# 6  1500         5.0                          Santa with Muscles (1996)
# 7  1536         5.0                               Aiqing wansui (1994)
# 8  1599         5.0                      Someone Else's America (1995)
# 9  1653         5.0  Entertaining Angels: The Dorothy Day Story (1996)
#
#   release_date
# 0  01-Jan-1994
# 1  01-Jan-1939
# 2  24-Jan-1997
# 3  02-Apr-1996
# 4  16-Jan-1998
# 5  01-Jan-1993
# 6  08-Nov-1996
# 7  22-Jul-1996
# 8  10-May-1996
# 9  27-Sep-1996
