# %%
#Isolation forest
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('RidingMowers.csv')

X=df.drop('Response',axis=1)
X
# Out:
#      Income  Lot_Size
# 0        34        26
# 1        34        40
# 2        34        46
# 3        34        48
# 4        34        53
# ..      ...       ...
# 175      86       121
# 176      87       109
# 177      88       119
# 178      89       110
# 179      89       124
#
# [180 rows x 2 columns]

# %%
clf=IsolationForest(contamination=0.05,random_state=23)
clf.fit(X)
predictions = clf.predict(X)

# %%
print("%age of outliers="+str((predictions<0).mean()*100)+"%")
abn_ind = np.where(predictions < 0)
# Out:
# %age of outliers=5.0%

# %%
plt.scatter(X.Income,X.Lot_Size,c="blue",label="Normal points")
plt.scatter(X['Income'].loc[abn_ind],
           X['Lot_Size'].loc[abn_ind],c="red",label="Outliers")

plt.legend()
plt.title("Riding Mowers")
plt.xlabel('Income')
plt.ylabel("Lot size")
plt.show()

# %% [markdown]
# # For Milk Dataset

# %%
df=pd.read_csv('milk.csv',index_col =0)
df
# Out:
#             water  protein   fat  lactose   ash
# Animal
# HORSE        90.1      2.6   1.0      6.9  0.35
# ORANGUTAN    88.5      1.4   3.5      6.0  0.24
# MONKEY       88.4      2.2   2.7      6.4  0.18
# DONKEY       90.3      1.7   1.4      6.2  0.40
# HIPPO        90.4      0.6   4.5      4.4  0.10
# CAMEL        87.7      3.5   3.4      4.8  0.71
# BISON        86.9      4.8   1.7      5.7  0.90
# BUFFALO      82.1      5.9   7.9      4.7  0.78
# GUINEA PIG   81.9      7.4   7.2      2.7  0.85
# CAT          81.6     10.1   6.3      4.4  0.75
# FOX          81.6      6.6   5.9      4.9  0.93
# LLAMA        86.5      3.9   3.2      5.6  0.80
# MULE         90.0      2.0   1.8      5.5  0.47
# PIG          82.8      7.1   5.1      3.7  1.10
# ZEBRA        86.2      3.0   4.8      5.3  0.70
# SHEEP        82.0      5.6   6.4      4.7  0.91
# DOG          76.3      9.3   9.5      3.0  1.20
# ELEPHANT     70.7      3.6  17.6      5.6  0.63
# ...

# %%
clf=IsolationForest(contamination=0.05,random_state=23)
clf.fit(df)
predictions = clf.predict(df)

# %%
print("%age of outliers="+str((predictions<0).mean()*100)+"%")
abn_ind = np.where(predictions < 0)
# Out:
# %age of outliers=8.0%

# %%
plt.scatter(df.Income,df.Lot_Size,c="blue",label="Normal points")
plt.scatter(df['I'].loc[abn_ind],
           df['Lot_Size'].loc[abn_ind],c="red",label="Outliers")

plt.legend()
plt.title("Milk Dataset")
plt.xlabel('Animals')
plt.ylabel("Lot si")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_26715/181459516.py in ?()
# ----> 1 plt.scatter(df.Income,df.Lot_Size,c="blue",label="Normal points")
#       2 plt.scatter(df['Income'].loc[abn_ind],
#       3            df['Lot_Size'].loc[abn_ind],c="red",label="Outliers")
#       4
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Income'
